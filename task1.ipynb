# %%
print("🎉 Welcome to My Python Program 🎉")

name = input("Enter your name: ")
age = input("Enter your age: ")
city = input("Enter your city: ")
hobby = input("Enter your favorite hobby: ")
dream = input("What is your dream job? ")

print(f"Hello {name}! 👋")
print(f"You are {age} years old.")
print(f"You live in {city}.")
print(f"Your favorite hobby is {hobby}.")
print(f"Your dream job is {dream}.")
print("Best of luck for your future! 🌟")
# Out:
# 🎉 Welcome to My Python Program 🎉
# ----------------------------------
# Enter your name:  Vikas
# Enter your age:  23
# Enter your city:  prayagraj
# Enter your favorite hobby:  cricket
# What is your dream job?  Data Scientist
# ========== SUMMARY ==========
# Hello Vikas! 👋
# You are 23 years old.
# You live in prayagraj.
# Your favorite hobby is cricket.
# Your dream job is Data Scientist.
# Best of luck for your future! 🌟
